# %% [markdown]
# ### Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading the data

# %%
data=pd.read_csv('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.csv')

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %% [markdown]
# #### CHECKING MISSING VALUE

# %%
# Checking Missing values
data.isnull().sum()
# No null value
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
# Check the duplicate value in dataset
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Conversion of categorical variables

# %%
data.describe(include='O').T
# Out:
#                         count unique              top  freq
# EmpNumber                1200   1200         E1001000     1
# Gender                   1200      2             Male   725
# EducationBackground      1200      6    Life Sciences   492
# MaritalStatus            1200      3          Married   548
# EmpDepartment            1200      6            Sales   373
# EmpJobRole               1200     19  Sales Executive   270
# BusinessTravelFrequency  1200      3    Travel_Rarely   846
# OverTime                 1200      2               No   847
# Attrition                1200      2               No  1022

# %%
# Get all categorical feature list
list(data.select_dtypes('object'))
# Out:
# ['EmpNumber',
#  'Gender',
#  'EducationBackground',
#  'MaritalStatus',
#  'EmpDepartment',
#  'EmpJobRole',
#  'BusinessTravelFrequency',
#  'OverTime',
#  'Attrition']

# %% [markdown]
# ### 1. Attrition

# %%
data.Attrition.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data.Attrition.value_counts()
# Out:
# Attrition
# No     1022
# Yes     178
# Name: count, dtype: int64

# %%
# manual encoding on attrition
data.Attrition=data.Attrition.map({'Yes':1,'No':0})
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %% [markdown]
# ### 2. BusinessTravelFrequency

# %%
data.BusinessTravelFrequency.unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
data.BusinessTravelFrequency.value_counts()
# Out:
# BusinessTravelFrequency
# Travel_Rarely        846
# Travel_Frequently    222
# Non-Travel           132
# Name: count, dtype: int64

# %%
data.BusinessTravelFrequency=data.BusinessTravelFrequency.map({'Travel_Frequently':2,'Travel_Rarely':1,'Non-Travel':0})
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole  BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive                        1                10
# 1  Sales Executive                        1                14
# 2  Sales Executive                        2                 5
# 3          Manager                        1                10
# 4  Sales Executive                        1                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %% [markdown]
# ### 3. EmpDepartment

# %%
data.EmpDepartment.value_counts()
# Out:
# EmpDepartment
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: count, dtype: int64

# %%
data.EmpDepartment=data.EmpDepartment.map({'Research & Development':3,'Sales':5,'Human Resources':2,'Development':4,'Data Science':0,'Finance':1})#imputation using map function
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus  EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single              5
# 1  E1001006   47   Male           Marketing        Single              5
# 2  E1001007   40   Male       Life Sciences       Married              5
# 3  E1001009   41   Male     Human Resources      Divorced              2
# 4  E1001010   60   Male           Marketing        Single              5
#
#         EmpJobRole  BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive                        1                10
# 1  Sales Executive                        1                14
# 2  Sales Executive                        2                 5
# 3          Manager                        1                10
# 4  Sales Executive                        1                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %% [markdown]
# ### 4. EducationBackground

# %%
data.EducationBackground.value_counts()
# Out:
# EducationBackground
# Life Sciences       492
# Medical             384
# Marketing           137
# Technical Degree    100
# Other                66
# Human Resources      21
# Name: count, dtype: int64

# %%
data.EducationBackground=data.EducationBackground.map({'Life Sciences':5,'Medical':4,'Marketing':3,'Technical Degree':2,'Other':1,'Human Resources':0 })

# %% [markdown]
# ### 5. Gender

# %%
data.Gender.value_counts()
# Out:
# Gender
# Male      725
# Female    475
# Name: count, dtype: int64

# %%
data.Gender=pd.get_dummies(data['Gender'],prefix='Gender',drop_first=True,dtype=int)
data.head()
# Out:
#   EmpNumber  Age  Gender  EducationBackground MaritalStatus  EmpDepartment  \
# 0  E1001000   32       1                    3        Single              5
# 1  E1001006   47       1                    3        Single              5
# 2  E1001007   40       1                    5       Married              5
# 3  E1001009   41       1                    0      Divorced              2
# 4  E1001010   60       1                    3        Single              5
#
#         EmpJobRole  BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive                        1                10
# 1  Sales Executive                        1                14
# 2  Sales Executive                        2                 5
# 3          Manager                        1                10
# 4  Sales Executive                        1                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %% [markdown]
# ### 6. EmpJobRole

# %%
data.EmpJobRole.value_counts()
# Out:
# EmpJobRole
# Sales Executive              270
# Developer                    236
# Manager R&D                   94
# Research Scientist            77
# Sales Representative          69
# Laboratory Technician         64
# Senior Developer              52
# Manager                       51
# Finance Manager               49
# Human Resources               45
# Technical Lead                38
# Manufacturing Director        33
# Healthcare Representative     33
# Data Scientist                20
# Research Director             19
# Business Analyst              16
# Senior Manager R&D            15
# Delivery Manager              12
# Technical Architect            7
# Name: count, dtype: int64

# %%
data.EmpJobRole=data.EmpJobRole.map({
'Sales Executive':18,
'Developer':17,
'Manager R&D':16,
'Research Scientist':15,
'Sales Representative':14,
'Laboratory Technician':13,
'Senior Developer':12,
'Manager':11,
'Finance Manager':10,
'Human Resources':9,
'Technical Lead':8,
'Manufacturing Director':7,
'Healthcare Representative':6,
'Data Scientist':5,
'Research Director':4,
'Business Analyst':3,
'Senior Manager R&D':2,
'Delivery Manager':1,
'Technical Architect':0})

# %%
data.EmpJobRole
# Out:
# 0       18
# 1       18
# 2       18
# 3       11
# 4       18
#         ..
# 1195    18
# 1196    12
# 1197    12
# 1198     5
# 1199    18
# Name: EmpJobRole, Length: 1200, dtype: int64

# %% [markdown]
# ### 7. MaritalStatus

# %%
data.MaritalStatus.value_counts()
# Out:
# MaritalStatus
# Married     548
# Single      384
# Divorced    268
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lr=LabelEncoder()
data.MaritalStatus=lr.fit_transform(data.MaritalStatus)
data.MaritalStatus
# Out:
# 0       2
# 1       2
# 2       1
# 3       0
# 4       2
#        ..
# 1195    0
# 1196    2
# 1197    1
# 1198    2
# 1199    2
# Name: MaritalStatus, Length: 1200, dtype: int32

# %% [markdown]
# ### 8. OverTime

# %%
data.OverTime.value_counts()
# Out:
# OverTime
# No     847
# Yes    353
# Name: count, dtype: int64

# %%
data.OverTime=lr.fit_transform(data.OverTime)#label encoding

# %% [markdown]
# ## Handling Outliers

# %%
data2= data[['Age','DistanceFromHome','EmpLastSalaryHikePercent','EmpHourlyRate',
'TotalWorkExperienceInYears','ExperienceYearsAtThisCompany','ExperienceYearsInCurrentRole','YearsWithCurrManager','YearsSinceLastPromotion']]


plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data2:
    if plotnumber<=16 :
        ax = plt.subplot(3,3,plotnumber)
        sns.boxplot(x=data2[column])
        plt.xlabel(column,fontsize=30)
        plt.ylabel('Count',fontsize=30)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data2:
    if plotnumber<=16 :
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(x=data2[column])
        
    plotnumber+=1
plt.tight_layout()

# %%
data.head()
# Out:
#   EmpNumber  Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  \
# 0  E1001000   32       1                    3              2              5
# 1  E1001006   47       1                    3              2              5
# 2  E1001007   40       1                    5              1              5
# 3  E1001009   41       1                    0              0              2
# 4  E1001010   60       1                    3              2              5
#
#    EmpJobRole  BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0          18                        1                10                  3
# 1          18                        1                14                  4
# 2          18                        2                 5                  4
# 3          11                        1                10                  4
# 4          18                        1                16                  4
#
# ...

# %% [markdown]
# #### TotalWorkExpierenceInYears

# %%
## Using Iqr to remove outliers
from scipy import stats
iqr= stats.iqr(data.TotalWorkExperienceInYears,interpolation='midpoint')
print(iqr)
q1=data.TotalWorkExperienceInYears.quantile(0.25)
q3=data.TotalWorkExperienceInYears.quantile(0.75)

#getting the limits
min_limit=q1 - 1.5*iqr

max_limit=q3 +1.5*iqr
print(min_limit)
print(max_limit)
# Out:
# 9.0
# -7.5
# 28.5

# %%
len(data.loc[data['TotalWorkExperienceInYears']>max_limit])/len(data)*100  #if more than 5% we wont handle outliers
# Out:
# 4.25

# %%
data.loc[data['TotalWorkExperienceInYears']>max_limit]
# Out:
#      EmpNumber  Age  Gender  EducationBackground  MaritalStatus  \
# 17    E1001040   56       1                    4              1
# 25    E1001054   52       1                    3              1
# 48    E1001093   50       1                    4              1
# 72    E1001129   51       0                    3              1
# 77    E1001140   53       0                    3              1
# 96    E1001179   53       0                    5              2
# 100   E1001183   50       1                    5              0
# 149   E1001275   50       1                    4              0
# 173   E1001310   59       0                    5              2
# 178   E1001316   52       0                    3              1
# 192   E1001339   50       1                    4              1
# 199   E1001352   55       1                    4              2
# 277   E1001493   50       0                    4              1
# 292   E1001523   54       0                    5              0
# ...

# %%
data.loc[data['TotalWorkExperienceInYears']>max_limit,'TotalWorkExperienceInYears']=np.median(data.TotalWorkExperienceInYears)

# %%
# filtering data after imputation
data.loc[data['TotalWorkExperienceInYears'] > max_limit]
# Out:
# Empty DataFrame
# Columns: [EmpNumber, Age, Gender, EducationBackground, MaritalStatus, EmpDepartment, EmpJobRole, BusinessTravelFrequency, DistanceFromHome, EmpEducationLevel, EmpEnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, TotalWorkExperienceInYears, TrainingTimesLastYear, EmpWorkLifeBalance, ExperienceYearsAtThisCompany, ExperienceYearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ### ExperienceYearsAtThisCompany

# %%
iqr=stats.iqr(data.ExperienceYearsAtThisCompany,interpolation='midpoint')
print(iqr)

q1=data.ExperienceYearsAtThisCompany.quantile(0.25)
q3=data.ExperienceYearsAtThisCompany.quantile(0.75)
min_limit= q1-iqr*1.5
max_limit=q3+iqr*1.5
print(min_limit)
print(max_limit)
# Out:
# 7.0
# -7.5
# 20.5

# %%
data.loc[data['ExperienceYearsAtThisCompany']>max_limit,'ExperienceYearsAtThisCompany']=np.median(data.ExperienceYearsAtThisCompany)

# %%
data.loc[data['ExperienceYearsAtThisCompany']>max_limit]
# Out:
# Empty DataFrame
# Columns: [EmpNumber, Age, Gender, EducationBackground, MaritalStatus, EmpDepartment, EmpJobRole, BusinessTravelFrequency, DistanceFromHome, EmpEducationLevel, EmpEnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, TotalWorkExperienceInYears, TrainingTimesLastYear, EmpWorkLifeBalance, ExperienceYearsAtThisCompany, ExperienceYearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ### ExperienceYearsInCurrentRole

# %%
# Use iqr range because some skewed in data
iqr = stats.iqr(data['ExperienceYearsInCurrentRole'],interpolation='midpoint')
print("IQR:",iqr)

q1=data.ExperienceYearsInCurrentRole.quantile(0.25)
q3=data.ExperienceYearsInCurrentRole.quantile(0.75)
min_limit= q1-iqr*1.5
max_limit=q3+iqr*1.5
print(min_limit)
print(max_limit)
# Out:
# IQR: 5.0
# -5.5
# 14.5

# %%
data.loc[data['ExperienceYearsInCurrentRole']>max_limit,'ExperienceYearsInCurrentRole']=np.median(data.ExperienceYearsInCurrentRole)

# %%
data.loc[data['ExperienceYearsInCurrentRole'] > max_limit]
# Out:
# Empty DataFrame
# Columns: [EmpNumber, Age, Gender, EducationBackground, MaritalStatus, EmpDepartment, EmpJobRole, BusinessTravelFrequency, DistanceFromHome, EmpEducationLevel, EmpEnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, TotalWorkExperienceInYears, TrainingTimesLastYear, EmpWorkLifeBalance, ExperienceYearsAtThisCompany, ExperienceYearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ### YearsWithCurrManager

# %%
iqr=stats.iqr(data.YearsWithCurrManager, interpolation='midpoint')
print(iqr)
q1= data.YearsWithCurrManager.quantile(0.25)
q3=data.YearsWithCurrManager.quantile(0.75)
min_limit= q1-iqr*1.5
max_limit=q3+iqr*1.5
print(min_limit)
print(max_limit)
# Out:
# 5.0
# -5.5
# 14.5

# %%
data.loc[data['YearsWithCurrManager']>max_limit,'YearsWithCurrManager']=np.median(data.YearsWithCurrManager)

# %%
data.loc[data['YearsWithCurrManager']>max_limit]
# Out:
# Empty DataFrame
# Columns: [EmpNumber, Age, Gender, EducationBackground, MaritalStatus, EmpDepartment, EmpJobRole, BusinessTravelFrequency, DistanceFromHome, EmpEducationLevel, EmpEnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, TotalWorkExperienceInYears, TrainingTimesLastYear, EmpWorkLifeBalance, ExperienceYearsAtThisCompany, ExperienceYearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ### YearsSinceLastPromotion

# %%
iqr= stats.iqr(data.YearsSinceLastPromotion, interpolation='midpoint')
print(iqr)
q1=data.YearsSinceLastPromotion.quantile(0.25)
q3=data.YearsSinceLastPromotion.quantile(0.75)
min_limit= q1-iqr*1.5
max_limit=q3+iqr*1.5
print(min_limit)
print(max_limit)
# Out:
# 3.0
# -4.5
# 7.5

# %%
data.loc[data['YearsSinceLastPromotion']>max_limit,'YearsSinceLastPromotion']=np.median(data.YearsSinceLastPromotion)

# %% [markdown]
# #### Training time last year

# %%
iqr = stats.iqr(data['TrainingTimesLastYear'],interpolation='midpoint')
print("IQR:",iqr)

# Getting first & third quantile
Q1 = data['TrainingTimesLastYear'].quantile(0.25)
Q3 = data['TrainingTimesLastYear'].quantile(0.75)

# Get maximum and minimum limit
min_limit = Q1 - 1.5*iqr
print("Minimum limit:",min_limit)

max_limit = Q3 + 1.5*iqr
print("Maximum Limit:",max_limit)
# Out:
# IQR: 1.0
# Minimum limit: 0.5
# Maximum Limit: 4.5

# %%
data.loc[data['TrainingTimesLastYear'] < min_limit,'TrainingTimesLastYear']=data['TrainingTimesLastYear'].median()
data.loc[data['TrainingTimesLastYear'] > max_limit,'TrainingTimesLastYear']=data['TrainingTimesLastYear'].median()

# %%
data.loc[data['TrainingTimesLastYear'] < min_limit]
# Out:
# Empty DataFrame
# Columns: [EmpNumber, Age, Gender, EducationBackground, MaritalStatus, EmpDepartment, EmpJobRole, BusinessTravelFrequency, DistanceFromHome, EmpEducationLevel, EmpEnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, TotalWorkExperienceInYears, TrainingTimesLastYear, EmpWorkLifeBalance, ExperienceYearsAtThisCompany, ExperienceYearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ### Feature Engg

# %%
data.head()
# Out:
#   EmpNumber  Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  \
# 0  E1001000   32       1                    3              2              5
# 1  E1001006   47       1                    3              2              5
# 2  E1001007   40       1                    5              1              5
# 3  E1001009   41       1                    0              0              2
# 4  E1001010   60       1                    3              2              5
#
#    EmpJobRole  BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0          18                        1                10                  3
# 1          18                        1                14                  4
# 2          18                        2                 5                  4
# 3          11                        1                10                  4
# 4          18                        1                16                  4
#
# ...

# %%
data.drop(['EmpNumber'],axis='columns',inplace=True)

# %%
data.corr()
# Out:
#                                    Age    Gender  EducationBackground  \
# Age                           1.000000 -0.040107             0.049544
# Gender                       -0.040107  1.000000            -0.021775
# EducationBackground           0.049544 -0.021775             1.000000
# MaritalStatus                -0.098368 -0.042169             0.028907
# EmpDepartment                -0.042295 -0.024570             0.024661
# EmpJobRole                   -0.088325  0.021370            -0.001630
# BusinessTravelFrequency      -0.011196 -0.042369            -0.015177
# DistanceFromHome              0.020937 -0.001507            -0.003118
# EmpEducationLevel             0.207313 -0.022960            -0.038661
# EmpEnvironmentSatisfaction    0.013814  0.000033            -0.045680
# EmpHourlyRate                 0.062867  0.002218             0.048646
# EmpJobInvolvement             0.027216  0.010949             0.026778
# ...

# %%
## Checking correlation

plt.figure(figsize=(30, 30))#canvas size
sns.heatmap(data.corr(), annot=True, annot_kws={"size":15})#plotting heat map to check correlation
# Out:
# <Axes: >

# %% [markdown]
# From above heatmap scale we are clearly seen the their is no highly correlated feature in data

# %%
data.head()
# Out:
#    Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  EmpJobRole  \
# 0   32       1                    3              2              5          18
# 1   47       1                    3              2              5          18
# 2   40       1                    5              1              5          18
# 3   41       1                    0              0              2          11
# 4   60       1                    3              2              5          18
#
#    BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0                        1                10                  3
# 1                        1                14                  4
# 2                        2                 5                  4
# 3                        1                10                  4
# 4                        1                16                  4
#
#    EmpEnvironmentSatisfaction  ...  EmpRelationshipSatisfaction  \
# ...

# %% [markdown]
# ### SAVE PRE-PROCESS DATA

# %%
data.to_csv('employee_performance_analysis_preprocessed_data.csv')
df = pd.read_csv('employee_performance_analysis_preprocessed_data.csv')
data.head()
# Out:
#    Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  EmpJobRole  \
# 0   32       1                    3              2              5          18
# 1   47       1                    3              2              5          18
# 2   40       1                    5              1              5          18
# 3   41       1                    0              0              2          11
# 4   60       1                    3              2              5          18
#
#    BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0                        1                10                  3
# 1                        1                14                  4
# 2                        2                 5                  4
# 3                        1                10                  4
# 4                        1                16                  4
#
#    EmpEnvironmentSatisfaction  ...  EmpRelationshipSatisfaction  \
# ...
